# %% [markdown]
# <a href="https://colab.research.google.com/github/Sujihari/Python-learning/blob/master/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/mckinsey.csv')

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Dataframe and Series

# dataframe is like full entire data set in the tabular column and check above example
# series is like one column, eg for series is below

# %%
df['country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
type(df['country'])
# Out:
# pandas.core.series.Series

# %%
# to get some infor about our data
df.info()

# here we gave 6columns and (Index) we call it as rows 1704, object means strings
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
# to check top 5 rows by default
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
#if you want top 10
df.head(10)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5  Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6  Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7  Afghanistan  1987    13867957      Asia    40.822  852.395945
# 8  Afghanistan  1992    16317921      Asia    41.674  649.341395
# 9  Afghanistan  1997    22227415      Asia    41.763  635.341351

# %%
#to check last 5 rows by default
df.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df.tail(10)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1694  Zimbabwe  1962     4277736    Africa    52.358  527.272182
# 1695  Zimbabwe  1967     4995432    Africa    53.995  569.795071
# 1696  Zimbabwe  1972     5861135    Africa    55.635  799.362176
# 1697  Zimbabwe  1977     6642107    Africa    57.674  685.587682
# 1698  Zimbabwe  1982     7636524    Africa    60.363  788.855041
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
# check shape
df.shape
# Out:
# (1704, 6)

# %%
#jzt to check the column
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.keys()
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df['country'].head() #by default it will give 5
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
#choosing multiple columns:Data frame (we have make list [])
df[['country','population','life_exp']].head()
# Out:
#        country  population  life_exp
# 0  Afghanistan     8425333    28.801
# 1  Afghanistan     9240934    30.332
# 2  Afghanistan    10267083    31.997
# 3  Afghanistan    11537966    34.020
# 4  Afghanistan    13079460    36.088

# %%
type(df[['country','population','life_exp']]) # data type is data frame
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['country']) # series data type
# Out:
# pandas.core.series.Series

# %%
type(df[['country']]) # datatype is dataframe (if you put [] then it will be dataframe)
# Out:
# pandas.core.frame.DataFrame

# %%
df[['country']].head(3) # it will give u like full dtaframe
# Out:
#        country
# 0  Afghanistan
# 1  Afghanistan
# 2  Afghanistan

# %%
df.country
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
# df['country] and df.country both will give the same answer but prefer df['country] bcz df. we have many functions like df.add, df.align , incase if columnname and function name will be same then some confusion will happen

# %%
#unique values in column
df['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
# pandas and numpy are close together , so it is numpy array
type(df['country'].unique())
# Out:
# numpy.ndarray

# %%
#to find length
len(df['country'].unique())
# Out:
# 142

# %%
#finding leng in another way (nunique)no.of unique
df['country'].nunique()
# Out:
# 142

# %%
#count of all unique values with the series :Value counts()
df['country'].value_counts()
# Out:
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: country, Length: 142, dtype: int64

# %%
#changing name of the column DataFrame.rename(mapper=None, *, index=None, columns=None, axis=None, copy=None, inplace=False, level=None, errors='ignore')[source]
#here mapper will work as dictionary{} and we need to mention rows aor column ,so use axis

df.rename({'population':'POPULATION'},axis = 1)
# Out:
#           country  year  POPULATION continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
#column name will not change in original dataframe, If you want to change in original dataframe means inplace option by default it is false, but if ypou give true then it will change in original dataframe also
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
#now changing in original dataframe (it is changed)
df.rename({'population':'POPULATION'},axis = 1,inplace = True)
df
# Out:
#           country  year  POPULATION continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
#delete the columns
df.drop('POPULATION', axis =1)
# Out:
#           country  year  life_exp     gdp_cap
# 0     Afghanistan  1952    28.801  779.445314
# 1     Afghanistan  1957    30.332  820.853030
# 2     Afghanistan  1962    31.997  853.100710
# 3     Afghanistan  1967    34.020  836.197138
# 4     Afghanistan  1972    36.088  739.981106
# ...           ...   ...       ...         ...
# 1699     Zimbabwe  1987    62.351  706.157306
# 1700     Zimbabwe  1992    60.377  693.420786
# 1701     Zimbabwe  1997    46.809  792.449960
# 1702     Zimbabwe  2002    39.989  672.038623
# 1703     Zimbabwe  2007    43.487  469.709298
#
# [1704 rows x 4 columns]

# %%
# another method for dele instead of axis
df.drop(columns = 'country').head()
# Out:
#    year  population continent  life_exp     gdp_cap  year+7
# 0  1952     8425333      Asia    28.801  779.445314    1959
# 1  1957     9240934      Asia    30.332  820.853030    1964
# 2  1962    10267083      Asia    31.997  853.100710    1969
# 3  1967    11537966      Asia    34.020  836.197138    1974
# 4  1972    13079460      Asia    36.088  739.981106    1979

# %%
#creating new columns
df['year+7'] = df['year']+7

# %%
#It will give the new column name year+7 and it will add each year with +7
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap  year+7
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314    1959
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030    1964
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710    1969
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138    1974
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106    1979

# %%
# caluclating the gdp_capita per person in  a country, Each person in a country will receive gdp_cap, so population * gdp_Cap
df['gdp'] = df['population'] * df['gdp_cap']

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap  year+7  \
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314    1959
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030    1964
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710    1969
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138    1974
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106    1979
#
#             gdp
# 0  6.567086e+09
# 1  7.585449e+09
# 2  8.758856e+09
# 3  9.648014e+09
# 4  9.678553e+09

# %%
# jzt simply we are adding simple row

df['new'] = 3
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap  year+7  \
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314    1959
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030    1964
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710    1969
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138    1974
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106    1979
#
#             gdp  new
# 0  6.567086e+09    3
# 1  7.585449e+09    3
# 2  8.758856e+09    3
# 3  9.648014e+09    3
# 4  9.678553e+09    3

# %%
# jzt to make series like serial no
df['series']= [i for i in range(len(df))]
df
# Out:
#           country  year  population continent  life_exp     gdp_cap  year+7  \
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314    1959
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030    1964
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710    1969
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138    1974
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106    1979
# ...           ...   ...         ...       ...       ...         ...     ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306    1994
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786    1999
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960    2004
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623    2009
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298    2014
#
#                gdp  new  series
# ...

# %%
# to drop newly added column
df.drop(columns = ['year+7','new','gdp','series'], inplace=True)

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
#operation  on rows (we have implicit indexing - by default o,1,2,3 it will created by itslef) (explicit indexing - we created as own)
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
# index start @ 0 and stop @1704 but 1704 is excluded... we have 1703
df.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
#it will give output as array
df.index.values
# Out:
# array([   0,    1,    2, ..., 1701, 1702, 1703])

# %%
df.index[1]
# Out:
# 1

# %%
#creating  explicit indexes(creating new indexes)
import numpy as np
new_indexing = np.arange(10, 1714) # already we have 0 to 1704 , now we are starting from 10 to 1714
new_indexing
# Out:
# array([  10,   11,   12, ..., 1711, 1712, 1713])

# %%
#now check index starts from 10 and ends 1713 ,bcz 1714 is excluded
df.index = new_indexing
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 10    Afghanistan  1952     8425333      Asia    28.801  779.445314
# 11    Afghanistan  1957     9240934      Asia    30.332  820.853030
# 12    Afghanistan  1962    10267083      Asia    31.997  853.100710
# 13    Afghanistan  1967    11537966      Asia    34.020  836.197138
# 14    Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1709     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1710     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1711     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1712     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1713     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
#predefined indexing : implicit
#defined by user : explicit
df.index[0]
# Out:
# 10

# %%
#here 1703 is implicit index ...for that explicit index is 1713
df.index[1703]
# Out:
# 1713

# %%
# another way of creating explicit index, here we are considering sample data with 5 data frames
sample_data = df.head()

# %%
sample_data.index = ['a','b','c','d','e']
sample_data
# Out:
#        country  year  population continent  life_exp     gdp_cap
# a  Afghanistan  1952     8425333      Asia    28.801  779.445314
# b  Afghanistan  1957     9240934      Asia    30.332  820.853030
# c  Afghanistan  1962    10267083      Asia    31.997  853.100710
# d  Afghanistan  1967    11537966      Asia    34.020  836.197138
# e  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
#loc and iloc
# extracting rows
# loc use only explicit index but if we are not having explicit index , loc will take implict index by default
df.loc[10]
# Out:
# country       Afghanistan
# year                 1952
# population        8425333
# continent            Asia
# life_exp           28.801
# gdp_cap        779.445314
# Name: 10, dtype: object

# %%
# to get last row
df.loc[1713]
# Out:
# country         Zimbabwe
# year                2007
# population      12311143
# continent         Africa
# life_exp          43.487
# gdp_cap       469.709298
# Name: 1713, dtype: object

# %%
#another way to get last row (here len(df) is 1704 and for 1713 is explicit index , 1704+9 is 1713 )
df.loc[len(df)+ 9]
# Out:
# country         Zimbabwe
# year                2007
# population      12311143
# continent         Africa
# life_exp          43.487
# gdp_cap       469.709298
# Name: 1713, dtype: object

# %%
#it will give bottom to top
df.loc[::-1]
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 1713     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1712     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1711     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1710     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1709     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# ...           ...   ...         ...       ...       ...         ...
# 14    Afghanistan  1972    13079460      Asia    36.088  739.981106
# 13    Afghanistan  1967    11537966      Asia    34.020  836.197138
# 12    Afghanistan  1962    10267083      Asia    31.997  853.100710
# 11    Afghanistan  1957     9240934      Asia    30.332  820.853030
# 10    Afghanistan  1952     8425333      Asia    28.801  779.445314
#
# [1704 rows x 6 columns]

# %%
#slicing
#silicing will include end of index and it will also use explicit index
df.loc[10:13]
# Out:
#         country  year  population continent  life_exp     gdp_cap
# 10  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 11  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 12  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 13  Afghanistan  1967    11537966      Asia    34.020  836.197138

# %%
# another non-unique index which we cannot slice
demo = pd.Series(['a','b','c','d','e'], index=[1,5,3,7,3])
demo.loc[1:3] #it will throws an error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-39178c296ede> in <cell line: 3>()
#       1 # another non-unique index which we cannot slice
#       2 demo = pd.Series(['a','b','c','d','e'], index=[1,5,3,7,3])
# ----> 3 demo.loc[1:3]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1071
#    1072             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073             return self._getitem_axis(maybe_callable, axis=axis)
#    1074
#    1075     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1288         if isinstance(key, slice):
#    1289             self._validate_key(key, axis)
# -> 1290             return self._get_slice_axis(key, axis=axis)
#    1291         elif com.is_bool_indexer(key):
# ...

# %%
#corresponding to the indexes values will be displayed
demo.loc[3]
# Out:
# 3    c
# 3    e
# dtype: object

# %%
#iloc - takes implicit indexing is called natural indexing and also support negatice index
df.iloc[0]
# Out:
# country       Afghanistan
# year                 1952
# population        8425333
# continent            Asia
# life_exp           28.801
# gdp_cap        779.445314
# Name: 10, dtype: object

# %%
#last row
df.iloc[-1]
# Out:
# country         Zimbabwe
# year                2007
# population      12311143
# continent         Africa
# life_exp          43.487
# gdp_cap       469.709298
# Name: 1713, dtype: object

# %%
#in iloc slicing end index is excluded
df.iloc[0:2]
# Out:
#         country  year  population continent  life_exp     gdp_cap
# 10  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 11  Afghanistan  1957     9240934      Asia    30.332  820.853030

# %%
df.iloc[:20]
# Out:
#         country  year  population continent  life_exp      gdp_cap
# 0   Afghanistan  1952     8425333      Asia    28.801   779.445314
# 1   Afghanistan  1957     9240934      Asia    30.332   820.853030
# 2   Afghanistan  1962    10267083      Asia    31.997   853.100710
# 3   Afghanistan  1967    11537966      Asia    34.020   836.197138
# 4   Afghanistan  1972    13079460      Asia    36.088   739.981106
# 5   Afghanistan  1977    14880372      Asia    38.438   786.113360
# 6   Afghanistan  1982    12881816      Asia    39.854   978.011439
# 7   Afghanistan  1987    13867957      Asia    40.822   852.395945
# 8   Afghanistan  1992    16317921      Asia    41.674   649.341395
# 9   Afghanistan  1997    22227415      Asia    41.763   635.341351
# 10  Afghanistan  2002    25268405      Asia    42.129   726.734055
# 11  Afghanistan  2007    31889923      Asia    43.828   974.580338
# 12      Albania  1952     1282697    Europe    55.230  1601.056136
# ...

# %%
#multiple rows using iloc
df.iloc[[0,1,3,5]]
# Out:
#         country  year  population continent  life_exp     gdp_cap
# 10  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 11  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 13  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 15  Afghanistan  1977    14880372      Asia    38.438  786.113360

# %%
#multiple rows using loc
df.loc[[10,11,12,14,15]]
# Out:
#         country  year  population continent  life_exp     gdp_cap
# 10  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 11  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 12  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 14  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 15  Afghanistan  1977    14880372      Asia    38.438  786.113360

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
#here index i mentioned (:) to display all rows
df.loc[:,['year', 'continent', 'country']]
# Out:
#       year continent      country
# 0     1952      Asia  Afghanistan
# 1     1957      Asia  Afghanistan
# 2     1962      Asia  Afghanistan
# 3     1967      Asia  Afghanistan
# 4     1972      Asia  Afghanistan
# ...    ...       ...          ...
# 1699  1987    Africa     Zimbabwe
# 1700  1992    Africa     Zimbabwe
# 1701  1997    Africa     Zimbabwe
# 1702  2002    Africa     Zimbabwe
# 1703  2007    Africa     Zimbabwe
#
# [1704 rows x 3 columns]

# %%
#suppose If i mentioned 1 in index
df.loc[1,['year', 'population', 'country']] # only index 1 will be displayed
# Out:
# year                 1957
# population        9240934
# country       Afghanistan
# Name: 1, dtype: object

# %%
df.iloc[:2,:2] # iloc excluded the end index so it is giving 0 and 1 index and 2 columns
# Out:
#        country  year
# 0  Afghanistan  1952
# 1  Afghanistan  1957

# %%
df.loc[:2, 'continent':'gdp_cap'] #loc it will included the end index so it is giving 0,1,and 2 and from continent till gdp_cap columns will be displayed
# Out:
#   continent  life_exp     gdp_cap
# 0      Asia    28.801  779.445314
# 1      Asia    30.332  820.853030
# 2      Asia    31.997  853.100710

# %%
df.iloc[1:5, 3:5] # it is iloc so end index and column should be excluded
# Out:
#   continent  life_exp
# 1      Asia    30.332
# 2      Asia    31.997
# 3      Asia    34.020
# 4      Asia    36.088

# %%
df.population
# Out:
# 0        8425333
# 1        9240934
# 2       10267083
# 3       11537966
# 4       13079460
#           ...
# 1699     9216418
# 1700    10704340
# 1701    11404948
# 1702    11926563
# 1703    12311143
# Name: population, Length: 1704, dtype: int64

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
new_df = df.loc[df.gdp_cap>900.00,['population']]

# %%
new_df
# Out:
#       population
# 6       12881816
# 11      31889923
# 12       1282697
# 13       1476505
# 14       1728137
# ...          ...
# 1687     7272406
# 1688     8381163
# 1689     9417789
# 1690    10595811
# 1691    11746035
#
# [1402 rows x 1 columns]
